# %%
# Native Python modules
import os, sys, csv, string

# Scipy/Numpy modules
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
# This loads the "pylab" environment into the current namespace: plotting from matplotlib and numerics/maths from numpy
# Also it makes plots show up together with the code output below each cell, rather than in a window
# %pylab inline
# For more 'magic functions', try running %magic

# Simple demonstration of Numpy uniform random generator
X = np.random.uniform(low=5, high=15, size=1000000)
h,b,p = hist(X,histtype='step',bins=100)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.special import erf

def phi(x):
    #'Cumulative distribution function for the standard normal distribution'
    return (1.0 + erf(x / sqrt(2.0))) / 2.0


x=np.linspace(-5,5,100)
plt.plot(x,phi(x))

# %%
invGaussian= lambda x: -1.0/(np.sqrt(2*np.pi))*np.exp(-np.power((x-3.5),2)/(2))
x=np.linspace(0,10,100)
plt.plot(x,invGaussian(x))

# %%
from scipy.optimize import minimize
minInvGaussian = minimize(invGaussian,4,bounds=[(0,10)])
print(minInvGaussian)
# Out:
#   status: 0
#  success: True
#     nfev: 10
#      fun: array([-0.39894228])
#        x: array([ 3.49999])
#  message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      jac: array([ -3.98570066e-06])
#      nit: 4
